# %% [markdown]
# **Power BI Visuals**
#
# **Question 1 : Create a Card Visual to show Total Sales.**
#
# **ANS:**
#
# ![image.png](data:image/png;base64,...)
#
# **Question 2  : Create a Donut Chart showing Total Sales by Ship Mode and which ship mode generates the highest sales?**
#
# **ANS:**
#
# ![image.png](data:image/png;base64,...)
#
# Standard Class generates the highest total sales.
#
# **Question 3 : Create a Line Chart showing the Sales Trend over time (by Month and Year). Is there any noticeable seasonal pattern in sales?**
#
# **ANS:**
#
# ![image.png](data:image/png;base64,...)
#
# The line chart shows an overall upward trend in sales over the years. There are noticeable monthly fluctuations indicating seasonality, with higher sales generally occurring toward the later months of each year.
#
# **Question 4 : Create a Bar Chart to compare Sales by Category.**
#
# **ANS:**
#
# ![image.png](data:image/png;base64,...)
#
# The bar chart compares total sales across categories. Technology has the highest sales, followed by Furniture, while Office Supplies has comparatively lower sales.
#
# **Question 5 : Create a Matrix Visual to display Sales by Month and Category and identify the month with the highest sales.**
#
# **ANS:**
#
# ![image.png](data:image/png;base64,...)
#
# The matrix visual shows total sales by month and category.
#
#  December has the highest total sales, followed by November and September, indicating stronger sales toward the end of the year.
#
# **Question 6 : Create a Decomposition Tree for Sales Breakdown.**
#
# **ANS:**
#
# ![image.png](data:image/png;base64,...)
#
# A decomposition tree was created to analyze sales breakdown. Technology category contributes the highest sales. Within Technology, Standard Class ship mode generates the most sales. The Central region contributes the highest within this, and the Consumer segment shows the highest contribution at the final level.
#
# **Question 7 : Create a Scatter Chart to compare Discount vs. Profit by Sub-Category. Are there any outliers where high discounts resulted in negative profit?**
#
# **ANS:**
#
# ![image.png](data:image/png;base64,...)
#
# The scatter chart compares Discount vs Profit by sub-category. An outlier is visible where the **Tables** sub-category shows negative profit despite higher discounts. This indicates that excessive discounting may reduce profitability for certain products.
#
# ![image.png](data:image/png;base64,...)
#
# **Question 8 : Use a Funnel Chart to show the number of orders by Customer Segment.**
#
# **ANS:**
#
# ![image.png](data:image/png;base64,...)
#
#
# The funnel chart displays the number of orders by customer segment. The Consumer segment has the highest number of orders, followed by Corporate, while Home Office has the lowest order count.
#
# **Question 9 : Use a Waterfall Chart to analyze how Profit changes by Category within the countries.**
#
# **ANS:**
#
# ![image.png](data:image/png;base64,...)
#
# The waterfall chart shows how profit changes across countries by category. Technology mostly increases profit, while some contributions from Furniture and Office Supplies reduce overall profit in certain countries.
#
# **Question 10 : Create a Dual-Axis Line Chart to show Total Sales and Profit Over Time (by Month).**
#
# **ANS:**
#
# ![image.png](data:image/png;base64,...)
#
# Sales and profit follow a similar monthly trend. Both increase toward later months, with noticeable growth from August to December, indicating stronger performance during the end of the year.
